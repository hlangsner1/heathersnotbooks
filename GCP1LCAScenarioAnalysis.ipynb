# %%
import pandas as pd
import numpy as np
import seaborn as sns
from numpy import random
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %%
num_simulations = 1000

# %%
results = pd.DataFrame(columns = ["transport", "application", "weathering"])

# %%
transport = random.normal(loc=46974.39, scale=2, size=(2, 3))
application = random.normal(loc=3408.23, scale=2, size=(2, 3))
weathering = random.normal(loc=133.81, scale=2, size=(2, 3))

# %%
total_impact = transport + application + weathering
total_impact
# Out:
# array([[50514.05129247, 50517.47384977, 50514.47765272],
#        [50514.16989623, 50517.97851438, 50515.3569195 ]])

# %%
sns.distplot(random.normal(size=1000), hist=False)
plt.show()
# Out:
# /opt/anaconda3/envs/p38/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
mean_impact = np.mean(total_impact)
std_impact = np.std(total_impact)

# %%
mean_impact
# Out:
# 50515.58468751108

# %%
std_impact
# Out:
# 1.5774282955908663
